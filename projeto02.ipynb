# %% [markdown]
# #### Buscar dados da ação automaticamente
#
# Bibliotecas: `yfinance` e `matplotlib`
#
# Instalar:
# - `pip install yfinance`
# - `pip install matplotlib`

# %% [markdown]
# #### TESTE

# %%
ticker = input("Digite o código da ação desejada: ")
data_inicial = input("Digite a data inicial (aaaa-mm-dd): ")
data_final = input("Digite a data final (aaaa-mm-dd): ")

dados = yfinance.Ticker(ticker).history(start=data_inicial, end=data_final).round(2)
fechamento = dados.Close
grafico = fechamento.plot()
fechamento
# Out:
# Date
# 2020-01-02 00:00:00-03:00    20.46
# 2020-01-03 00:00:00-03:00    20.43
# 2020-01-06 00:00:00-03:00    20.16
# 2020-01-07 00:00:00-03:00    20.01
# 2020-01-08 00:00:00-03:00    19.83
#                              ...
# 2020-12-22 00:00:00-03:00    15.15
# 2020-12-23 00:00:00-03:00    15.40
# 2020-12-28 00:00:00-03:00    15.57
# 2020-12-29 00:00:00-03:00    15.48
# 2020-12-30 00:00:00-03:00    15.35
# Name: Close, Length: 248, dtype: float64

# %% [markdown]
# #### Criar as análises solicitadas
#
# - Cotação máxima
# - Cotação mínima
# - Valor médio

# %%
maxima = fechamento.max().round(2)
minima = fechamento.min().round(2)
valor_medio = fechamento.mean().round(2)

print(maxima)
print(minima)
print(valor_medio)
# Out:
# 20.46
# 8.54
# 13.69
